# %% [markdown]
# # Parallel pipieline

# %%
import time# Sys
import sys
import os

# Numerical
import numpy as np
import mrcfile
import healpy as hp
# Plotting
import matplotlib.pyplot as plt
# Signal proc / Linalg
from scipy import ndimage
from scipy import signal
from scipy.ndimage import rotate
from scipy.fftpack import fft2, ifft2, fftshift
from skimage import filters, feature, transform
# Optimization
import multiprocessing
from itertools import product
from joblib import Parallel, delayed
from scipy.ndimage import affine_transform

# %%
# Functions

def read_mrc_file(file_path):
    """Reads a volume from an MRC file."""
    if not os.path.isfile(file_path):
        print(f"Error: File '{file_path}' not found.")
        sys.exit(1)
    try:
        with mrcfile.open(file_path, permissive=True) as mrc:
            volume = mrc.data.astype(np.float32)
            voxel_size = mrc.voxel_size
            if volume.ndim != 3:
                print("Error: Input volume is not 3-dimensional.")
                sys.exit(1)
    except Exception as e:
        print(f"Error reading MRC file: {e}")
        sys.exit(1)
    return volume, voxel_size

def generate_healpix_pixel_bounds(nside):
    """Generates boundaries of theta and phi for each Healpix pixel."""
    npix = hp.nside2npix(nside)
    pixel_bounds = []
    for pix in range(npix):
        # Get the boundary vertices for this pixel
        vertices = hp.boundaries(nside, pix, step=1, nest=False)  # shape (3, N)
        # Convert x, y, z to theta, phi
        theta_vertices, phi_vertices = hp.vec2ang(vertices.T)  # Transpose to shape (N, 3)
        # Adjust phi to be in [0, 2π)
        phi_vertices = phi_vertices % (2 * np.pi)
        # Handle phi wrapping around 0 and 2π
        phi_diff = np.diff(np.sort(phi_vertices))
        if np.any(phi_diff > np.pi):
            # Correct for wrapping
            phi_vertices[phi_vertices < np.pi] += 2 * np.pi
        # Update min and max after correction
        phi_min = phi_vertices.min() % (2 * np.pi)
        phi_max = phi_vertices.max() % (2 * np.pi)
        theta_min = theta_vertices.min()
        theta_max = theta_vertices.max()
        pixel_bounds.append((theta_min, theta_max, phi_min, phi_max))
    return pixel_bounds

def generate_angles_in_pixel(theta_min, theta_max, phi_min, phi_max, angular_spacing_rad):
    # Generate theta values from theta_min to theta_max with steps of angular_spacing_rad
    theta_vals = np.arange(theta_min, theta_max, angular_spacing_rad)
    # Handle phi wrapping
    if phi_max >= phi_min:
        phi_vals = np.arange(phi_min, phi_max, angular_spacing_rad)
    else:
        # phi_max < phi_min due to wrapping around 2π
        phi_vals_part1 = np.arange(phi_min, 2 * np.pi, angular_spacing_rad)
        phi_vals_part2 = np.arange(0, phi_max, angular_spacing_rad)
        phi_vals = np.concatenate((phi_vals_part1, phi_vals_part2))
    # Create grid of theta and phi values
    theta_grid, phi_grid = np.meshgrid(theta_vals, phi_vals, indexing='ij')
    # Adjust phi_grid to be in [0, 2π)
    phi_grid = phi_grid % (2 * np.pi)
    return theta_grid.flatten(), phi_grid.flatten()

def generate_all_angles(nside, angular_spacing_deg):
    angular_spacing_rad = np.radians(angular_spacing_deg)
    pixel_bounds = generate_healpix_pixel_bounds(nside)
    phi_angles_list = []
    theta_angles_list = []
    for idx, (theta_min, theta_max, phi_min, phi_max) in enumerate(pixel_bounds):
        theta_vals, phi_vals = generate_angles_in_pixel(
            theta_min, theta_max, phi_min, phi_max, angular_spacing_rad
        )
        phi_angles_list.append(phi_vals)
        theta_angles_list.append(theta_vals)
        print(f"Pixel {idx + 1}/{len(pixel_bounds)}: Generated {len(theta_vals)} angles")
    # Concatenate all angles
    phi_angles = np.concatenate(phi_angles_list)
    theta_angles = np.concatenate(theta_angles_list)
    return phi_angles, theta_angles

# Define the band-pass filter function
def bandpass_filter(img, low_sigma, high_sigma):
    low_pass = ndimage.gaussian_filter(img, high_sigma)
    high_pass = img - ndimage.gaussian_filter(img, low_sigma)
    return high_pass - low_pass

def rotate_and_project_opt(volume, phi, theta, psi):
    """Efficiently rotates the volume and projects it along the Z-axis."""
    # Compute combined rotation matrix
    cos_phi, sin_phi = np.cos(np.radians(phi)), np.sin(np.radians(phi))
    cos_theta, sin_theta = np.cos(np.radians(theta)), np.sin(np.radians(theta))
    cos_psi, sin_psi = np.cos(np.radians(psi)), np.sin(np.radians(psi))

    # Rotation matrices for each axis
    R_phi = np.array([
        [cos_phi, -sin_phi, 0],
        [sin_phi, cos_phi, 0],
        [0, 0, 1]
    ])

    R_theta = np.array([
        [cos_theta, 0, sin_theta],
        [0, 1, 0],
        [-sin_theta, 0, cos_theta]
    ])

    R_psi = np.array([
        [cos_psi, -sin_psi, 0],
        [sin_psi, cos_psi, 0],
        [0, 0, 1]
    ])

    # Combined rotation matrix
    R = R_psi @ R_theta @ R_phi

    # Center the volume for rotation
    center = np.array(volume.shape) / 2
    offset = center - R @ center

    # Apply affine transformation (rotation)
    rotated = affine_transform(volume, R, offset=offset, order=1)

    # Project along Z-axis
    projection = np.sum(rotated, axis=0)

    return projection

# %%
def cross_correlate_top_left(image, template):
    # Ensure the template is zero-padded to the size of the image
    template_padded = np.zeros_like(image)
    template_shape = template.shape
    # Place the template at the top-left corner of the padded array
    template_padded[:template_shape[0], :template_shape[1]] = template

    # Compute the FFTs
    image_fft = fft2(image)
    template_fft = fft2(template_padded)

    # Compute cross-correlation
    cross_corr = np.real(ifft2(image_fft * np.conj(template_fft)))

    # Normalize the cross-correlation
    # Compute local sums for normalization (using convolution with ones)
    template_sum = np.sum(template ** 2)
    image_local_sums = ndimage.uniform_filter(image ** 2, size=template_shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero

    normalized_cross_corr = cross_corr / denominator
    return normalized_cross_corr

# %%
import numpy as np
from scipy.signal import fftconvolve
from scipy.ndimage import uniform_filter

def cross_correlate_fourier_opt(image, template):
    # Compute cross-correlation using fftconvolve
    cross_corr = fftconvolve(image, template[::-1, ::-1], mode='same')
    
    # Normalize the cross-correlation
    template_sum = np.sum(template ** 2)
    image_local_sums = uniform_filter(image ** 2, size=template.shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr = cross_corr / denominator
    
    return normalized_cross_corr

# %%
import numpy as np
from scipy.fft import fft2, ifft2
from scipy.ndimage import uniform_filter

def cross_correlate_fourier(image, template):
    # Ensure the template is zero-padded to the size of the image
    template_padded = np.zeros_like(image)
    template_shape = template.shape
    # Place the template at the top-left corner of the padded array
    template_padded[:template_shape[0], :template_shape[1]] = template
    
    # Compute the FFTs
    image_fft = fft2(image)
    template_fft = fft2(template_padded)
    
    # Compute cross-correlation in Fourier space
    cross_corr = np.real(ifft2(image_fft * np.conj(template_fft)))
    
    # Normalize the cross-correlation
    template_sum = np.sum(template ** 2)
    image_local_sums = uniform_filter(image ** 2, size=template_shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr = cross_corr / denominator
    
    return normalized_cross_corr

# %%
import cupy as cp
from scipy.ndimage import uniform_filter

def cross_correlate_fourier_gpu(image, template):
    # Convert image and template to GPU arrays
    image_gpu = cp.asarray(image)
    template_gpu = cp.asarray(template)
    
    # Compute cross-correlation using fftconvolve on GPU
    cross_corr_gpu = cp.fft.ifft2(cp.fft.fft2(image_gpu) * cp.conj(cp.fft.fft2(template_gpu, s=image_gpu.shape))).real
    
    # Normalize the cross-correlation
    template_sum = cp.sum(template_gpu ** 2)
    image_local_sums = cp.asarray(uniform_filter(cp.asnumpy(image_gpu ** 2), size=template.shape))
    denominator = cp.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr_gpu = cross_corr_gpu / denominator
    
    # Convert result back to CPU array
    normalized_cross_corr = cp.asnumpy(normalized_cross_corr_gpu)
    
    return normalized_cross_corr

# %%
def process_combination(volume, phi, theta, psi, I_filtered, projection_shape, ncc_max, ncc_mean, ncc_M2, n):
    """Process a single combination of angles and update relevant statistics."""
    # Rotate and project
    projection = rotate_and_project(volume, phi, theta, psi)

    # Check Dimensions
    if projection.shape != projection_shape:
        print(f"Warning: Projection dimensions {projection.shape} do not match expected shape {projection_shape}.")

    # Normalize projection
    projection = projection - np.mean(projection)

    # Band pass filter the projection
    proj_filtered = bandpass_filter(projection, low_sigma=1, high_sigma=5)

    # Normalize the filtered projection
    T_mean = np.mean(proj_filtered)
    T_std = np.std(proj_filtered)
    T_norm = (proj_filtered - T_mean) / T_std

    # Calculate cross-correlation
    cross_corr = cross_correlate_top_left(I_filtered, T_norm)

    # Update max elements
    local_ncc_max = np.maximum(ncc_max, cross_corr)

    # Update mean and variance using Welford's algorithm
    local_n = n + 1
    delta = cross_corr - ncc_mean
    local_ncc_mean = ncc_mean + delta / local_n
    delta2 = cross_corr - local_ncc_mean
    local_ncc_M2 = ncc_M2 + delta * delta2

    return local_ncc_max, local_ncc_mean, local_ncc_M2, local_n

# Prepare the input arguments for parallel processing
def parallelize_processing(volume, phi_angles, theta_angles, psi_angles, I_filtered, projection_shape):
    # Shared initial values
    ncc_max = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_mean = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_M2 = np.zeros_like(I_filtered, dtype=np.float32)
    n = 0

    # Generate all combinations of angles
    angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]

    # Process combinations in parallel
    results = Parallel(n_jobs=-1)(
        delayed(process_combination)(
            volume, phi, theta, psi, I_filtered, projection_shape, ncc_max, ncc_mean, ncc_M2, n
        ) for phi, theta, psi in angle_combinations
    )

    # Aggregate results
    for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
        ncc_max = np.maximum(ncc_max, local_ncc_max)
        ncc_mean = local_ncc_mean
        ncc_M2 = local_ncc_M2
        n = local_n

    # Calculate the variance
    ncc_variance = ncc_M2 / (n - 1) if n > 1 else np.zeros_like(I_filtered, dtype=np.float32)

    return ncc_max, ncc_mean, ncc_variance

# Prepare the input arguments for parallel processing
def parallelize_processing1(volume, phi_angles, theta_angles, psi_angles, I_filtered):
    # Shared initial values
    ncc_max = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_mean = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_M2 = np.zeros_like(I_filtered, dtype=np.float32)
    n = 0

    # Generate all combinations of angles
    angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]

    # Process combinations in parallel
    results = Parallel(n_jobs=-1)(
        delayed(process_combination1)(
            volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n
        ) for phi, theta, psi in angle_combinations
    )

    # Aggregate results
    for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
        ncc_max = np.maximum(ncc_max, local_ncc_max)
        ncc_mean = local_ncc_mean
        ncc_M2 = local_ncc_M2
        n = local_n

    # Calculate the variance
    ncc_variance = ncc_M2 / (n - 1) if n > 1 else np.zeros_like(I_filtered, dtype=np.float32)

    return ncc_max, ncc_mean, ncc_variance

def process_combination1(volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n):
    """Process a single combination of angles and update relevant statistics."""
    start_time = time.time()
    # Rotate and project
    projection = rotate_and_project_opt(volume, phi, theta, psi)

    # Check Dimensions
    #if projection.shape != projection_shape:
    #    print(f"Warning: Projection dimensions {projection.shape} do not match expected shape {projection_shape}.")

    # Normalize projection
    projection = projection - np.mean(projection)

    # Band pass filter the projection
    proj_filtered = bandpass_filter(projection, low_sigma=1, high_sigma=5)

    # Normalize the filtered projection
    T_mean = np.mean(proj_filtered)
    T_std = np.std(proj_filtered)
    T_norm = (proj_filtered - T_mean) / T_std

    # Calculate cross-correlation
    #cross_corr = cross_correlate_fourier_opt(I_filtered, T_norm)
    cross_corr = cross_correlate_fourier_gpu(I_filtered, T_norm)
    
    
    # Update max elements
    local_ncc_max = np.maximum(ncc_max, cross_corr)

    # Update mean and variance using Welford's algorithm
    local_n = n + 1
    delta = cross_corr - ncc_mean
    local_ncc_mean = ncc_mean + delta / local_n
    delta2 = cross_corr - local_ncc_mean
    local_ncc_M2 = ncc_M2 + delta * delta2
    end_time = time.time()
    print(f"Cross correlation complete for : {phi, theta, psi} in {end_time-start_time} seconds")
    return local_ncc_max, local_ncc_mean, local_ncc_M2, local_n

# %%
if __name__ == "__main__":
    # Initialize necessary variables here (e.g., volume, phi_angles, theta_angles, psi_angles, etc.)
    # Example:
    # volume = ...
    #volume_file = input("Enter the path to the input MRC volume file: ").strip()
    volume_file = '0_data/7ood.mrc'
    volume, voxel_size = read_mrc_file(volume_file)
    # Get nside from the user
    try:
        nside = int(input("Enter NSIDE parameter (must be a power of 2 integer): "))
        if not hp.isnsideok(nside):
            raise ValueError
    except ValueError:
        print("Error: NSIDE must be a valid power of 2 integer.")
        sys.exit(1)

    print(f"Using NSIDE = {nside} for Healpix sampling.")

    # Get angular spacing from the user
    try:
        angular_spacing = float(input("Enter angular spacing in degrees: "))
        if angular_spacing <= 0:
            raise ValueError
    except ValueError:
        print("Error: Angular spacing must be a positive number.")
        sys.exit(1)
    # phi_angles = ...
    # theta_angles = ...
    # psi_angles = ...
    # Generate phi and theta angles
    phi_angles, theta_angles = generate_all_angles(nside, angular_spacing)
    print(f"Generated {len(phi_angles)} orientations using Healpix.")

    # Generate psi angles
    try:
        psi_step = float(input("Enter psi angular step in degrees: "))
        if psi_step <= 0:
            raise ValueError
    except ValueError:
        print("Error: Psi angular step must be a positive number.")
        sys.exit(1)

    psi_angles = np.arange(0, 360, psi_step)
    print(f"Using {len(psi_angles)} in-plane rotations (psi angles).")

    # Total number of projections
    total_projections = len(phi_angles) * len(psi_angles)
    print(f"Total number of projections to generate: {total_projections}")
    # I_filtered = ...
    with mrcfile.open('0_data/00040_3_0_wctf.mrc', permissive=True) as mrc:
        I = np.squeeze(mrc.data.astype(np.float32))
    # Apply the band-pass filter to the micrograph
    I_filtered = bandpass_filter(I, low_sigma=1, high_sigma=5)
    
    ncc_max, ncc_mean, ncc_variance = parallelize_processing1(
        volume, phi_angles, theta_angles, psi_angles, I_filtered,
    )
# Out:
# Using NSIDE = 1 for Healpix sampling.
# Pixel 1/12: Generated 9 angles
# Pixel 2/12: Generated 18 angles
# Pixel 3/12: Generated 27 angles
# Pixel 4/12: Generated 9 angles
# Pixel 5/12: Generated 12 angles
# Pixel 6/12: Generated 9 angles
# Pixel 7/12: Generated 9 angles
# Pixel 8/12: Generated 12 angles
# Pixel 9/12: Generated 9 angles
# Pixel 10/12: Generated 18 angles
# Pixel 11/12: Generated 27 angles
# Pixel 12/12: Generated 9 angles
# Generated 168 orientations using Healpix.
# Using 12 in-plane rotations (psi angles).
# Total number of projections to generate: 2016
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 90.0) in 59.7474639415741 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 330.0) in 59.964335203170776 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 150.0) in 60.21707057952881 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 0.0) in 59.8497416973114 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 330.0) in 59.852198362350464 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 180.0) in 61.33496928215027 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 0.0) in 60.29923462867737 seconds
# Cross correlation complete for : (0.0, 0.0, 300.0) in 61.52471733093262 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 0.0) in 0.3311021327972412 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 30.0) in 0.308361291885376 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 60.0) in 0.3081545829772949 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 90.0) in 0.32530927658081055 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 120.0) in 0.3202359676361084 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 150.0) in 0.3184549808502197 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 0.33641886711120605 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 210.0) in 0.31311678886413574 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 240.0) in 0.32749223709106445 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 270.0) in 0.3318600654602051 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 180.0) in 62.21760082244873 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 300.0) in 0.3149843215942383 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 330.0) in 0.3099796772003174 seconds
# Cross correlation complete for : (0.0, 0.0, 0.0) in 0.3377714157104492 seconds
# Cross correlation complete for : (0.0, 0.0, 30.0) in 0.30957531929016113 seconds
# Cross correlation complete for : (0.0, 0.0, 60.0) in 0.31360459327697754 seconds
# Cross correlation complete for : (0.0, 0.0, 90.0) in 0.34273529052734375 seconds
# Cross correlation complete for : (0.0, 0.0, 120.0) in 0.3122081756591797 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 240.0) in 63.44061899185181 seconds
# Cross correlation complete for : (0.0, 0.0, 150.0) in 0.3174269199371338 seconds
# Cross correlation complete for : (0.0, 0.0, 180.0) in 0.3285846710205078 seconds
# Cross correlation complete for : (0.0, 0.0, 210.0) in 0.33986330032348633 seconds
# Cross correlation complete for : (0.0, 0.0, 240.0) in 0.30194854736328125 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 330.0) in 64.59500694274902 seconds
# Cross correlation complete for : (0.0, 0.0, 270.0) in 0.3633573055267334 seconds
# Cross correlation complete for : (0.0, 0.0, 300.0) in 0.30841898918151855 seconds
# Cross correlation complete for : (0.0, 0.0, 330.0) in 0.33097386360168457 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 0.0) in 0.31658434867858887 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 30.0) in 0.3270547389984131 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 60.0) in 0.36965227127075195 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 60.0) in 65.50642585754395 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 90.0) in 0.41310572624206543 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 120.0) in 0.30941224098205566 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 150.0) in 0.3449440002441406 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 180.0) in 0.3592357635498047 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 210.0) in 0.32250237464904785 seconds
# Cross correlation complete for : (0.0, 0.0, 180.0) in 68.13339519500732 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 90.0) in 66.70275664329529 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 240.0) in 0.39478516578674316 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 270.0) in 0.3134777545928955 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 300.0) in 0.34616827964782715 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 330.0) in 0.2981696128845215 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 270.0) in 68.31439113616943 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 0.0) in 0.38556361198425293 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 30.0) in 0.3929734230041504 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 60.0) in 0.3841118812561035 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 90.0) in 0.3526585102081299 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 120.0) in 0.30413222312927246 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 150.0) in 0.37516307830810547 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 180.0) in 0.3221287727355957 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 210.0) in 0.3031783103942871 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 0.0) in 70.86028742790222 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 210.0) in 71.03137612342834 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 240.0) in 0.428149938583374 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 270.0) in 0.4158482551574707 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 300.0) in 0.3978745937347412 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 330.0) in 0.2956995964050293 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 0.0) in 0.39221644401550293 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 30.0) in 0.3025681972503662 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 60.0) in 0.3805091381072998 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 90.0) in 0.39405298233032227 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 120.0) in 0.36881470680236816 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 150.0) in 0.39067888259887695 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 180.0) in 0.4089393615722656 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 210.0) in 0.31342458724975586 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 240.0) in 0.3855278491973877 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 270.0) in 0.32956385612487793 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 300.0) in 0.3024716377258301 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 330.0) in 0.39214062690734863 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 0.0) in 0.39708495140075684 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 30.0) in 0.38350772857666016 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 60.0) in 0.3830540180206299 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 90.0) in 0.4286994934082031 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 120.0) in 0.33457183837890625 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 150.0) in 0.378345251083374 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 180.0) in 0.3373994827270508 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 210.0) in 0.39184093475341797 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 240.0) in 0.3939847946166992 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 270.0) in 0.4199788570404053 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 300.0) in 0.39937925338745117 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 330.0) in 0.32137298583984375 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 0.0) in 0.39458203315734863 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 30.0) in 0.40357398986816406 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 60.0) in 0.30410337448120117 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 90.0) in 0.3459279537200928 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 120.0) in 0.3862013816833496 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 150.0) in 0.35802745819091797 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 180.0) in 0.4101989269256592 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 210.0) in 0.38510894775390625 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 240.0) in 0.3819091320037842 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 270.0) in 0.33008813858032227 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 300.0) in 0.38585591316223145 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 330.0) in 0.325286865234375 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 0.0) in 0.39451026916503906 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 30.0) in 0.4005746841430664 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 60.0) in 0.4197423458099365 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 90.0) in 0.32384181022644043 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 120.0) in 0.38107728958129883 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 150.0) in 0.3914978504180908 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 180.0) in 0.3367495536804199 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 210.0) in 0.3996238708496094 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 240.0) in 0.3300793170928955 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 240.0) in 82.30603289604187 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 270.0) in 0.4093616008758545 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 300.0) in 0.38585591316223145 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 330.0) in 0.38491249084472656 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 0.0) in 0.40395259857177734 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 30.0) in 0.30956387519836426 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 60.0) in 0.31189417839050293 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 90.0) in 0.347304105758667 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 120.0) in 0.32912254333496094 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 150.0) in 0.39189696311950684 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 180.0) in 0.4100682735443115 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 210.0) in 0.30895423889160156 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 240.0) in 0.38657712936401367 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 270.0) in 0.3848123550415039 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 300.0) in 0.31517958641052246 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 330.0) in 0.39298224449157715 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 0.0) in 0.3382253646850586 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 30.0) in 0.39919400215148926 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 60.0) in 0.30136704444885254 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 90.0) in 0.3863663673400879 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 120.0) in 0.3872992992401123 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 150.0) in 0.3589789867401123 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 180.0) in 0.3259546756744385 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 210.0) in 0.37323665618896484 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 240.0) in 0.3051450252532959 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 270.0) in 0.40009188652038574 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 300.0) in 0.35466575622558594 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 330.0) in 0.3952462673187256 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 0.0) in 0.3457014560699463 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 30.0) in 0.379666805267334 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 60.0) in 0.3234567642211914 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 90.0) in 0.3375537395477295 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 120.0) in 0.3371100425720215 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 150.0) in 0.3201749324798584 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 180.0) in 0.3633759021759033 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 210.0) in 0.39293766021728516 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 240.0) in 0.30814123153686523 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 270.0) in 0.39348340034484863 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 300.0) in 0.3935086727142334 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 330.0) in 0.39743494987487793 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 0.0) in 0.3280327320098877 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 30.0) in 0.38246774673461914 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 60.0) in 0.302903413772583 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 90.0) in 0.37697815895080566 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 120.0) in 0.32972264289855957 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 150.0) in 0.32825613021850586 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 180.0) in 0.3361532688140869 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 240.0) in 0.36768555641174316 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 270.0) in 0.33878040313720703 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 210.0) in 0.6782879829406738 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 300.0) in 0.3921236991882324 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 330.0) in 0.3187267780303955 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 0.0) in 0.3899271488189697 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 30.0) in 0.3066987991333008 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 60.0) in 0.34435176849365234 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 90.0) in 0.39618444442749023 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 120.0) in 0.384554386138916 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 150.0) in 0.32097887992858887 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 180.0) in 0.3616600036621094 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 210.0) in 0.4142577648162842 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 240.0) in 0.32961201667785645 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 270.0) in 0.40952229499816895 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 330.0) in 0.3141655921936035 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 300.0) in 0.6499810218811035 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 0.0) in 0.3316805362701416 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 30.0) in 0.37263941764831543 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 60.0) in 0.30904698371887207 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 90.0) in 0.39348530769348145 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 120.0) in 0.38721179962158203 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 150.0) in 0.3156707286834717 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 180.0) in 0.3310263156890869 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 210.0) in 0.33683300018310547 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 240.0) in 0.5172061920166016 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 270.0) in 0.3868846893310547 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 300.0) in 0.3403136730194092 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 330.0) in 0.37870216369628906 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 0.0) in 0.401719331741333 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 30.0) in 0.31395936012268066 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 60.0) in 0.3816037178039551 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 90.0) in 0.41646647453308105 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 120.0) in 0.37486839294433594 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 150.0) in 0.3443939685821533 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 180.0) in 0.32812023162841797 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 210.0) in 0.38605713844299316 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 240.0) in 0.5148522853851318 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 270.0) in 0.42151880264282227 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 330.0) in 0.32735300064086914 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 300.0) in 0.5634684562683105 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 0.0) in 0.3245837688446045 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 30.0) in 0.33028674125671387 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 60.0) in 0.39060211181640625 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 90.0) in 0.39824533462524414 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 120.0) in 0.32077479362487793 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 150.0) in 0.3817415237426758 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 0.3397488594055176 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 210.0) in 0.380892276763916 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 240.0) in 0.39595484733581543 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 270.0) in 0.4144747257232666 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 300.0) in 0.34391355514526367 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 330.0) in 0.31870484352111816 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 0.0) in 0.3263697624206543 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 30.0) in 0.3259880542755127 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 60.0) in 0.31879448890686035 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 90.0) in 0.3762173652648926 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 120.0) in 0.3227999210357666 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 150.0) in 0.37830662727355957 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 180.0) in 0.32335376739501953 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 240.0) in 0.3334770202636719 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 270.0) in 0.347461462020874 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 210.0) in 0.8964347839355469 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 300.0) in 0.4060699939727783 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 330.0) in 0.463348388671875 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 0.0) in 0.4247760772705078 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 30.0) in 0.3543703556060791 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 60.0) in 0.37624478340148926 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 90.0) in 0.3250236511230469 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 120.0) in 0.32538342475891113 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 150.0) in 0.32128167152404785 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 180.0) in 0.33797407150268555 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 210.0) in 0.32041382789611816 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 240.0) in 0.32331252098083496 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 270.0) in 0.3352985382080078 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 300.0) in 0.3234224319458008 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 330.0) in 0.3210735321044922 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 0.0) in 0.3292529582977295 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 30.0) in 0.33533668518066406 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 60.0) in 0.3107874393463135 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 90.0) in 0.3491060733795166 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 120.0) in 0.38362979888916016 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 150.0) in 0.38201165199279785 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 180.0) in 0.3309299945831299 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 210.0) in 0.36536073684692383 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 240.0) in 0.3506922721862793 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 270.0) in 0.33650779724121094 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 300.0) in 0.35161709785461426 seconds
# Cross correlation complete for : (2.617993877991494, 1.0471975511965976, 330.0) in 0.33510804176330566 seconds
# Cross correlation complete for : (0.0, 0.0, 0.0) in 0.33944082260131836 seconds
# Cross correlation complete for : (0.0, 0.0, 30.0) in 0.3319084644317627 seconds
# Cross correlation complete for : (0.0, 0.0, 60.0) in 0.3248898983001709 seconds
# Cross correlation complete for : (0.0, 0.0, 90.0) in 0.3270127773284912 seconds
# Cross correlation complete for : (0.0, 0.0, 120.0) in 0.314866304397583 seconds
# Cross correlation complete for : (0.0, 0.0, 150.0) in 0.33211517333984375 seconds
# Cross correlation complete for : (0.0, 0.0, 180.0) in 0.3332653045654297 seconds
# Cross correlation complete for : (0.0, 0.0, 210.0) in 0.33461737632751465 seconds
# Cross correlation complete for : (0.0, 0.0, 240.0) in 0.3341186046600342 seconds
# Cross correlation complete for : (0.0, 0.0, 270.0) in 0.34897518157958984 seconds
# Cross correlation complete for : (0.0, 0.0, 300.0) in 0.3389768600463867 seconds
# Cross correlation complete for : (0.0, 0.0, 330.0) in 0.3262674808502197 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 0.0) in 0.33098459243774414 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 30.0) in 0.329693078994751 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 60.0) in 110.22985029220581 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 60.0) in 0.39809751510620117 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 90.0) in 0.3657224178314209 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 90.0) in 110.67426681518555 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 150.0) in 110.55201315879822 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 210.0) in 110.65415501594543 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 330.0) in 110.70210313796997 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 120.0) in 0.5059630870819092 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 150.0) in 0.35975217819213867 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 180.0) in 0.33620572090148926 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 210.0) in 0.32597947120666504 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 150.0) in 111.31564927101135 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 240.0) in 0.31876635551452637 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 120.0) in 111.81287956237793 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 270.0) in 0.3674275875091553 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 300.0) in 111.71971917152405 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 300.0) in 0.33505797386169434 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 330.0) in 0.3519704341888428 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 0.0) in 0.3232567310333252 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 150.0) in 112.35583758354187 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 30.0) in 0.32141971588134766 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 60.0) in 0.3503262996673584 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 90.0) in 0.3632059097290039 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 120.0) in 0.3508598804473877 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 150.0) in 0.36012887954711914 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 180.0) in 0.32114362716674805 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 210.0) in 0.348419189453125 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 240.0) in 0.39859676361083984 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 270.0) in 0.41216254234313965 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 300.0) in 0.30914807319641113 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 330.0) in 0.3111097812652588 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 0.0) in 0.3544647693634033 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 30.0) in 0.3307991027832031 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 240.0) in 114.85580158233643 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 60.0) in 0.39055800437927246 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 120.0) in 115.15936946868896 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 90.0) in 0.4361755847930908 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 120.0) in 0.40753674507141113 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 150.0) in 0.32341933250427246 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 270.0) in 115.9296293258667 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 180.0) in 0.36281514167785645 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 210.0) in 0.37331485748291016 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 0.0) in 116.47851729393005 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 240.0) in 0.33950257301330566 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 270.0) in 0.33081912994384766 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 300.0) in 0.3289780616760254 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 90.0) in 116.59106492996216 seconds
# Cross correlation complete for : (1.5707963267948966, 0.0, 330.0) in 0.4187490940093994 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 0.0) in 0.31496095657348633 seconds
# Cross correlation complete for : (0.0, 0.0, 0.0) in 118.69996380805969 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 30.0) in 0.3847336769104004 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 60.0) in 0.3137814998626709 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 90.0) in 0.31292104721069336 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 120.0) in 0.31847453117370605 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 150.0) in 0.3264951705932617 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 180.0) in 0.37097620964050293 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 210.0) in 0.3537881374359131 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 240.0) in 0.3457214832305908 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 270.0) in 0.34493398666381836 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 300.0) in 0.34506726264953613 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 330.0) in 0.3156406879425049 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 0.0) in 0.31505560874938965 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 30.0) in 0.3315606117248535 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 60.0) in 0.31626009941101074 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 90.0) in 0.33319973945617676 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 120.0) in 0.33065056800842285 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 150.0) in 0.3076505661010742 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 180.0) in 0.392566442489624 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 210.0) in 0.32758522033691406 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 240.0) in 0.37423181533813477 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 270.0) in 0.34978818893432617 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 300.0) in 0.3173825740814209 seconds
# Cross correlation complete for : (2.617993877991494, 0.0, 330.0) in 0.30478692054748535 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 0.0) in 0.33350324630737305 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 30.0) in 0.3083624839782715 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 60.0) in 0.3695814609527588 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 210.0) in 122.14501643180847 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 90.0) in 0.351975679397583 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 120.0) in 0.32811546325683594 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 180.0) in 122.2774269580841 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 150.0) in 0.3174118995666504 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 180.0) in 0.32393956184387207 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 210.0) in 0.31985902786254883 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 240.0) in 0.3143653869628906 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 270.0) in 0.3526785373687744 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 300.0) in 0.3303368091583252 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 330.0) in 0.37316131591796875 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 0.0) in 0.3271942138671875 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 30.0) in 0.3152034282684326 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 60.0) in 0.3256247043609619 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 90.0) in 0.3254563808441162 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 120.0) in 0.4006011486053467 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 150.0) in 0.3207571506500244 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 180.0) in 0.3345820903778076 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 210.0) in 0.33647680282592773 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 240.0) in 0.3195674419403076 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 270.0) in 0.33019590377807617 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 300.0) in 0.3365650177001953 seconds
# Cross correlation complete for : (3.665191429188092, 0.0, 330.0) in 0.3321688175201416 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 0.0) in 0.33698248863220215 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 30.0) in 0.3168928623199463 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 60.0) in 0.32153916358947754 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 90.0) in 0.3703432083129883 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 120.0) in 127.92047452926636 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 30.0) in 126.69155049324036 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 120.0) in 0.3538038730621338 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 150.0) in 0.33879518508911133 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 180.0) in 0.37011289596557617 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 210.0) in 127.59092998504639 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 210.0) in 0.3739323616027832 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 60.0) in 128.68460297584534 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 180.0) in 128.66569185256958 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 240.0) in 0.36325836181640625 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 270.0) in 0.3406205177307129 seconds
# Cross correlation complete for : (0.0, 0.0, 60.0) in 129.30308723449707 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 30.0) in 127.943767786026 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 300.0) in 0.32335734367370605 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 330.0) in 0.3928384780883789 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 300.0) in 128.37079548835754 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 0.0) in 0.4138355255126953 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 30.0) in 0.35175347328186035 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 180.0) in 128.53939533233643 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 60.0) in 0.36940979957580566 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 90.0) in 0.3292663097381592 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 120.0) in 0.31073784828186035 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 150.0) in 0.3187134265899658 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 180.0) in 0.33515143394470215 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 210.0) in 0.3138236999511719 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 240.0) in 0.3265388011932373 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 270.0) in 0.3484792709350586 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 300.0) in 0.3184831142425537 seconds
# Cross correlation complete for : (0.0, 0.5235987755982988, 330.0) in 0.31543540954589844 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 0.0) in 0.3249368667602539 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 30.0) in 0.31789636611938477 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 60.0) in 0.3507258892059326 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 90.0) in 0.334047794342041 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 120.0) in 0.3460378646850586 seconds
# Cross correlation complete for : (0.5235987755982988, 0.0, 300.0) in 131.56938123703003 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 150.0) in 0.32517075538635254 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 180.0) in 0.35987067222595215 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 210.0) in 0.3453085422515869 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 240.0) in 0.3334791660308838 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 270.0) in 0.36084890365600586 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 300.0) in 0.3248717784881592 seconds
# Cross correlation complete for : (0.5235987755982988, 0.5235987755982988, 330.0) in 0.3299276828765869 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 0.0) in 0.32763171195983887 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 30.0) in 0.3181188106536865 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 60.0) in 0.33295702934265137 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 90.0) in 0.3215634822845459 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 120.0) in 0.31990957260131836 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 150.0) in 0.3776857852935791 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 180.0) in 0.3557627201080322 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 210.0) in 0.3200676441192627 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 240.0) in 0.34182000160217285 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 270.0) in 0.32840895652770996 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 300.0) in 0.3322625160217285 seconds
# Cross correlation complete for : (1.0471975511965976, 0.5235987755982988, 330.0) in 0.32878756523132324 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 0.0) in 0.3386664390563965 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 30.0) in 0.3362135887145996 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 60.0) in 0.30917978286743164 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 90.0) in 0.3974418640136719 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 120.0) in 0.391204833984375 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 150.0) in 0.38054561614990234 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 180.0) in 0.41359615325927734 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 210.0) in 0.32050514221191406 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 240.0) in 0.32633519172668457 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 270.0) in 0.34110403060913086 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 300.0) in 0.3298799991607666 seconds
# Cross correlation complete for : (1.5707963267948966, 0.5235987755982988, 330.0) in 0.3521103858947754 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 0.0) in 0.31582045555114746 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 30.0) in 0.3777947425842285 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 60.0) in 0.3130354881286621 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 90.0) in 0.32575130462646484 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 120.0) in 0.3491394519805908 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 150.0) in 0.31061768531799316 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 180.0) in 0.3267989158630371 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 210.0) in 0.3143455982208252 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 240.0) in 0.33806848526000977 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 270.0) in 0.3439064025878906 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 300.0) in 0.31333065032958984 seconds
# Cross correlation complete for : (2.0943951023931953, 0.5235987755982988, 330.0) in 0.3524026870727539 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 0.0) in 0.3236351013183594 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 30.0) in 0.31779956817626953 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 60.0) in 0.31597900390625 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 90.0) in 0.3496084213256836 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 120.0) in 0.3209719657897949 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 150.0) in 0.31551384925842285 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 180.0) in 0.35476112365722656 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 210.0) in 0.32361268997192383 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 240.0) in 0.3446378707885742 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 270.0) in 0.3618137836456299 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 300.0) in 0.31586432456970215 seconds
# Cross correlation complete for : (2.617993877991494, 0.5235987755982988, 330.0) in 0.34720492362976074 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 0.0) in 0.321826696395874 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 30.0) in 0.3090384006500244 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 60.0) in 0.3236422538757324 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 90.0) in 0.37824583053588867 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 120.0) in 0.3368403911590576 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 150.0) in 0.3127615451812744 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 180.0) in 0.3191490173339844 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 210.0) in 0.31973791122436523 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 240.0) in 0.31965017318725586 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 270.0) in 0.33121299743652344 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 300.0) in 0.35948848724365234 seconds
# Cross correlation complete for : (3.141592653589793, 0.5235987755982988, 330.0) in 0.3551452159881592 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 0.0) in 0.3902473449707031 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 30.0) in 0.3915746212005615 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 60.0) in 0.3115272521972656 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 90.0) in 0.3308544158935547 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 120.0) in 0.3347513675689697 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 150.0) in 0.3237636089324951 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 180.0) in 0.33429980278015137 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 210.0) in 0.3190131187438965 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 240.0) in 0.33762550354003906 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 270.0) in 0.4690437316894531 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 300.0) in 0.385286808013916 seconds
# Cross correlation complete for : (3.665191429188092, 0.5235987755982988, 330.0) in 0.33217430114746094 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 0.0) in 0.33106231689453125 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 30.0) in 0.3335838317871094 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 60.0) in 0.3072352409362793 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 90.0) in 0.40715694427490234 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 120.0) in 0.3205103874206543 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 150.0) in 0.33171916007995605 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 180.0) in 0.33768463134765625 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 210.0) in 0.31569814682006836 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 240.0) in 0.315157413482666 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 270.0) in 0.3260769844055176 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 300.0) in 0.3156719207763672 seconds
# Cross correlation complete for : (4.1887902047863905, 0.5235987755982988, 330.0) in 0.32704877853393555 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 0.0) in 0.6195511817932129 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 30.0) in 0.48203086853027344 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 60.0) in 0.3110225200653076 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 90.0) in 0.3568871021270752 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 120.0) in 0.34621310234069824 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 150.0) in 0.3303232192993164 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 180.0) in 0.3302466869354248 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 210.0) in 0.3851466178894043 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 240.0) in 0.36858630180358887 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 270.0) in 0.3320631980895996 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 300.0) in 0.528989315032959 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 330.0) in 0.44563770294189453 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 0.0) in 0.3610403537750244 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 30.0) in 0.3765857219696045 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 60.0) in 0.31711912155151367 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 90.0) in 0.3302578926086426 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 120.0) in 0.33145833015441895 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 240.0) in 152.52394080162048 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 150.0) in 0.35829949378967285 seconds
# Cross correlation complete for : (0.0, 0.0, 240.0) in 152.51807618141174 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 180.0) in 0.3535647392272949 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 210.0) in 0.3816354274749756 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 240.0) in 0.32731175422668457 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 270.0) in 0.33663368225097656 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 300.0) in 0.32149481773376465 seconds
# Cross correlation complete for : (0.5235987755982988, 1.0471975511965976, 330.0) in 0.3578634262084961 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 0.0) in 0.3256251811981201 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 30.0) in 0.3759763240814209 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 60.0) in 0.32132935523986816 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 90.0) in 0.335862398147583 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 120.0) in 0.31584835052490234 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 150.0) in 0.3340308666229248 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 0.32215142250061035 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 210.0) in 0.358318567276001 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 240.0) in 0.32094478607177734 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 300.0) in 0.3226158618927002 seconds
# Cross correlation complete for : (1.5707963267948966, 1.0471975511965976, 60.0) in 0.33471012115478516 seconds
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/tmp/ipykernel_3671673/68292519.py", line 119, in process_combination1
#   File "/tmp/ipykernel_3671673/285950068.py", line 6, in cross_correlate_fourier_gpu
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/cupy/_creation/from_data.py", line 88, in asarray
#     return _core.array(a, dtype, False, order, blocking=blocking)
#   File "cupy/_core/core.pyx", line 2408, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2435, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2578, in cupy._core.core._array_default
#   File "cupy/_core/core.pyx", line 137, in cupy._core.core.ndarray.__new__
#   File "cupy/_core/core.pyx", line 225, in cupy._core.core._ndarray_base._init
#   File "cupy/cuda/memory.pyx", line 738, in cupy.cuda.memory.alloc
#   File "cupy/cuda/memory.pyx", line 1424, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1445, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1116, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1137, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc
#   File "cupy/cuda/memory.pyx", line 1382, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
#   File "cupy/cuda/memory.pyx", line 1385, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
# cupy.cuda.memory.OutOfMemoryError: Out of memory allocating 46,190,592 bytes (allocated so far: 0 bytes).
# """
#
# The above exception was the direct cause of the following exception:
#
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 55
#      52 # Apply the band-pass filter to the micrograph
#      53 I_filtered = bandpass_filter(I, low_sigma=1, high_sigma=5)
# ---> 55 ncc_max, ncc_mean, ncc_variance = parallelize_processing1(
#      56     volume, phi_angles, theta_angles, psi_angles, I_filtered,
#      57 )
#
# Cell In[7], line 78, in parallelize_processing1(volume, phi_angles, theta_angles, psi_angles, I_filtered)
#      75 angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]
#      77 # Process combinations in parallel
# ---> 78 results = Parallel(n_jobs=-1)(
#      79     delayed(process_combination1)(
#      80         volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n
#      81     ) for phi, theta, psi in angle_combinations
#      82 )
#      84 # Aggregate results
#      85 for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# OutOfMemoryError: Out of memory allocating 46,190,592 bytes (allocated so far: 0 bytes).

# %%
# Display the results
plt.figure(figsize=(6, 6))
plt.imshow(ncc_max, cmap='gray')
plt.title('Max Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()

plt.figure(figsize=(6, 6))
plt.imshow(ncc_mean, cmap='gray')
plt.title('Mean Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()

plt.figure(figsize=(6, 6))
plt.imshow(ncc_variance, cmap='gray')
plt.title('Variance Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()


# Aggregate the correlation maps by taking the maximum at each pixel
mip = (ncc_max - ncc_mean)/np.sqrt(ncc_variance)

# Display the aggregated cross-correlation map
plt.figure(figsize=(6, 6))
plt.imshow(mip, cmap='gray')
plt.title('Aggregated MIP map')
plt.colorbar()
plt.axis('off')
plt.show()

# %%
# Count the number of elements above 8
num_elements_above_8 = np.sum(mip > 7.43)
print(f"Number of elements in mip_scaled above 8: {num_elements_above_8}")

# %%
# Find the row and column indices of values greater than 7 in the mip array
indices = np.where(mip > 7.43)
rows, cols = indices

# Print the row and column indices in pairs
for row, col in zip(rows, cols):
    print(f"Row: {row}, Col: {col}")

# %%
plt.figure(figsize=(6, 6))
plt.imshow(I_filtered, cmap='gray')

# Add circles for each pair of coordinates
for col, row in zip(cols, rows):
	circle = plt.Circle((col, row), radius=50, color='red', fill=False, linewidth=0.2)
	plt.gca().add_patch(circle)

#plt.scatter(cols, rows, c='red', s=1)
plt.title('Row, Col Indices on Image I')
plt.axis('off')
plt.show()
