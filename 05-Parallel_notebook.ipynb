# %% [markdown]
# # Parallel pipieline

# %%
import time# Sys
import sys
import os

# Numerical
import numpy as np
import mrcfile
import healpy as hp
# Plotting
import matplotlib.pyplot as plt
# Signal proc / Linalg
from scipy import ndimage
from scipy import signal
from scipy.ndimage import rotate
from scipy.fftpack import fft2, ifft2, fftshift
from skimage import filters, feature, transform
# Optimization
import multiprocessing
from itertools import product
from joblib import Parallel, delayed
from scipy.ndimage import affine_transform

# %%
# Functions

def read_mrc_file(file_path):
    """Reads a volume from an MRC file."""
    if not os.path.isfile(file_path):
        print(f"Error: File '{file_path}' not found.")
        sys.exit(1)
    try:
        with mrcfile.open(file_path, permissive=True) as mrc:
            volume = mrc.data.astype(np.float32)
            voxel_size = mrc.voxel_size
            if volume.ndim != 3:
                print("Error: Input volume is not 3-dimensional.")
                sys.exit(1)
    except Exception as e:
        print(f"Error reading MRC file: {e}")
        sys.exit(1)
    return volume, voxel_size

def generate_healpix_pixel_bounds(nside):
    """Generates boundaries of theta and phi for each Healpix pixel."""
    npix = hp.nside2npix(nside)
    pixel_bounds = []
    for pix in range(npix):
        # Get the boundary vertices for this pixel
        vertices = hp.boundaries(nside, pix, step=1, nest=False)  # shape (3, N)
        # Convert x, y, z to theta, phi
        theta_vertices, phi_vertices = hp.vec2ang(vertices.T)  # Transpose to shape (N, 3)
        # Adjust phi to be in [0, 2π)
        phi_vertices = phi_vertices % (2 * np.pi)
        # Handle phi wrapping around 0 and 2π
        phi_diff = np.diff(np.sort(phi_vertices))
        if np.any(phi_diff > np.pi):
            # Correct for wrapping
            phi_vertices[phi_vertices < np.pi] += 2 * np.pi
        # Update min and max after correction
        phi_min = phi_vertices.min() % (2 * np.pi)
        phi_max = phi_vertices.max() % (2 * np.pi)
        theta_min = theta_vertices.min()
        theta_max = theta_vertices.max()
        pixel_bounds.append((theta_min, theta_max, phi_min, phi_max))
    return pixel_bounds

def generate_angles_in_pixel(theta_min, theta_max, phi_min, phi_max, angular_spacing_rad):
    # Generate theta values from theta_min to theta_max with steps of angular_spacing_rad
    theta_vals = np.arange(theta_min, theta_max, angular_spacing_rad)
    # Handle phi wrapping
    if phi_max >= phi_min:
        phi_vals = np.arange(phi_min, phi_max, angular_spacing_rad)
    else:
        # phi_max < phi_min due to wrapping around 2π
        phi_vals_part1 = np.arange(phi_min, 2 * np.pi, angular_spacing_rad)
        phi_vals_part2 = np.arange(0, phi_max, angular_spacing_rad)
        phi_vals = np.concatenate((phi_vals_part1, phi_vals_part2))
    # Create grid of theta and phi values
    theta_grid, phi_grid = np.meshgrid(theta_vals, phi_vals, indexing='ij')
    # Adjust phi_grid to be in [0, 2π)
    phi_grid = phi_grid % (2 * np.pi)
    return theta_grid.flatten(), phi_grid.flatten()

def generate_all_angles(nside, angular_spacing_deg):
    angular_spacing_rad = np.radians(angular_spacing_deg)
    pixel_bounds = generate_healpix_pixel_bounds(nside)
    phi_angles_list = []
    theta_angles_list = []
    for idx, (theta_min, theta_max, phi_min, phi_max) in enumerate(pixel_bounds):
        theta_vals, phi_vals = generate_angles_in_pixel(
            theta_min, theta_max, phi_min, phi_max, angular_spacing_rad
        )
        phi_angles_list.append(phi_vals)
        theta_angles_list.append(theta_vals)
        print(f"Pixel {idx + 1}/{len(pixel_bounds)}: Generated {len(theta_vals)} angles")
    # Concatenate all angles
    phi_angles = np.concatenate(phi_angles_list)
    theta_angles = np.concatenate(theta_angles_list)
    return phi_angles, theta_angles

# Define the band-pass filter function
def bandpass_filter(img, low_sigma, high_sigma):
    low_pass = ndimage.gaussian_filter(img, high_sigma)
    high_pass = img - ndimage.gaussian_filter(img, low_sigma)
    return high_pass - low_pass

def rotate_and_project_opt(volume, phi, theta, psi):
    """Efficiently rotates the volume and projects it along the Z-axis."""
    # Compute combined rotation matrix
    cos_phi, sin_phi = np.cos(np.radians(phi)), np.sin(np.radians(phi))
    cos_theta, sin_theta = np.cos(np.radians(theta)), np.sin(np.radians(theta))
    cos_psi, sin_psi = np.cos(np.radians(psi)), np.sin(np.radians(psi))

    # Rotation matrices for each axis
    R_phi = np.array([
        [cos_phi, -sin_phi, 0],
        [sin_phi, cos_phi, 0],
        [0, 0, 1]
    ])

    R_theta = np.array([
        [cos_theta, 0, sin_theta],
        [0, 1, 0],
        [-sin_theta, 0, cos_theta]
    ])

    R_psi = np.array([
        [cos_psi, -sin_psi, 0],
        [sin_psi, cos_psi, 0],
        [0, 0, 1]
    ])

    # Combined rotation matrix
    R = R_psi @ R_theta @ R_phi

    # Center the volume for rotation
    center = np.array(volume.shape) / 2
    offset = center - R @ center

    # Apply affine transformation (rotation)
    rotated = affine_transform(volume, R, offset=offset, order=1)

    # Project along Z-axis
    projection = np.sum(rotated, axis=0)

    return projection

# %%
def cross_correlate_top_left(image, template):
    # Ensure the template is zero-padded to the size of the image
    template_padded = np.zeros_like(image)
    template_shape = template.shape
    # Place the template at the top-left corner of the padded array
    template_padded[:template_shape[0], :template_shape[1]] = template

    # Compute the FFTs
    image_fft = fft2(image)
    template_fft = fft2(template_padded)

    # Compute cross-correlation
    cross_corr = np.real(ifft2(image_fft * np.conj(template_fft)))

    # Normalize the cross-correlation
    # Compute local sums for normalization (using convolution with ones)
    template_sum = np.sum(template ** 2)
    image_local_sums = ndimage.uniform_filter(image ** 2, size=template_shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero

    normalized_cross_corr = cross_corr / denominator
    return normalized_cross_corr

# %%
import numpy as np
from scipy.signal import fftconvolve
from scipy.ndimage import uniform_filter

def cross_correlate_fourier_opt(image, template):
    # Compute cross-correlation using fftconvolve
    cross_corr = fftconvolve(image, template[::-1, ::-1], mode='same')
    
    # Normalize the cross-correlation
    template_sum = np.sum(template ** 2)
    image_local_sums = uniform_filter(image ** 2, size=template.shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr = cross_corr / denominator
    
    return normalized_cross_corr

# %%
import numpy as np
from scipy.fft import fft2, ifft2
from scipy.ndimage import uniform_filter

def cross_correlate_fourier(image, template):
    # Ensure the template is zero-padded to the size of the image
    template_padded = np.zeros_like(image)
    template_shape = template.shape
    # Place the template at the top-left corner of the padded array
    template_padded[:template_shape[0], :template_shape[1]] = template
    
    # Compute the FFTs
    image_fft = fft2(image)
    template_fft = fft2(template_padded)
    
    # Compute cross-correlation in Fourier space
    cross_corr = np.real(ifft2(image_fft * np.conj(template_fft)))
    
    # Normalize the cross-correlation
    template_sum = np.sum(template ** 2)
    image_local_sums = uniform_filter(image ** 2, size=template_shape)
    denominator = np.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr = cross_corr / denominator
    
    return normalized_cross_corr

# %%
import cupy as cp
from scipy.ndimage import uniform_filter

def cross_correlate_fourier_gpu(image, template):
    # Convert image and template to GPU arrays
    image_gpu = cp.asarray(image)
    template_gpu = cp.asarray(template)
    
    # Compute cross-correlation using fftconvolve on GPU
    cross_corr_gpu = cp.fft.ifft2(cp.fft.fft2(image_gpu) * cp.conj(cp.fft.fft2(template_gpu, s=image_gpu.shape))).real
    
    # Normalize the cross-correlation
    template_sum = cp.sum(template_gpu ** 2)
    image_local_sums = cp.asarray(uniform_filter(cp.asnumpy(image_gpu ** 2), size=template.shape))
    denominator = cp.sqrt(template_sum * image_local_sums)
    denominator[denominator == 0] = 1  # Prevent division by zero
    normalized_cross_corr_gpu = cross_corr_gpu / denominator
    
    # Convert result back to CPU array
    normalized_cross_corr = cp.asnumpy(normalized_cross_corr_gpu)
    
    return normalized_cross_corr

# %%
def process_combination(volume, phi, theta, psi, I_filtered, projection_shape, ncc_max, ncc_mean, ncc_M2, n):
    """Process a single combination of angles and update relevant statistics."""
    # Rotate and project
    projection = rotate_and_project(volume, phi, theta, psi)

    # Check Dimensions
    if projection.shape != projection_shape:
        print(f"Warning: Projection dimensions {projection.shape} do not match expected shape {projection_shape}.")

    # Normalize projection
    projection = projection - np.mean(projection)

    # Band pass filter the projection
    proj_filtered = bandpass_filter(projection, low_sigma=1, high_sigma=5)

    # Normalize the filtered projection
    T_mean = np.mean(proj_filtered)
    T_std = np.std(proj_filtered)
    T_norm = (proj_filtered - T_mean) / T_std

    # Calculate cross-correlation
    cross_corr = cross_correlate_top_left(I_filtered, T_norm)

    # Update max elements
    local_ncc_max = np.maximum(ncc_max, cross_corr)

    # Update mean and variance using Welford's algorithm
    local_n = n + 1
    delta = cross_corr - ncc_mean
    local_ncc_mean = ncc_mean + delta / local_n
    delta2 = cross_corr - local_ncc_mean
    local_ncc_M2 = ncc_M2 + delta * delta2

    return local_ncc_max, local_ncc_mean, local_ncc_M2, local_n

# Prepare the input arguments for parallel processing
def parallelize_processing(volume, phi_angles, theta_angles, psi_angles, I_filtered, projection_shape):
    # Shared initial values
    ncc_max = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_mean = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_M2 = np.zeros_like(I_filtered, dtype=np.float32)
    n = 0

    # Generate all combinations of angles
    angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]

    # Process combinations in parallel
    results = Parallel(n_jobs=-1)(
        delayed(process_combination)(
            volume, phi, theta, psi, I_filtered, projection_shape, ncc_max, ncc_mean, ncc_M2, n
        ) for phi, theta, psi in angle_combinations
    )

    # Aggregate results
    for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
        ncc_max = np.maximum(ncc_max, local_ncc_max)
        ncc_mean = local_ncc_mean
        ncc_M2 = local_ncc_M2
        n = local_n

    # Calculate the variance
    ncc_variance = ncc_M2 / (n - 1) if n > 1 else np.zeros_like(I_filtered, dtype=np.float32)

    return ncc_max, ncc_mean, ncc_variance

# Prepare the input arguments for parallel processing
def parallelize_processing1(volume, phi_angles, theta_angles, psi_angles, I_filtered):
    # Shared initial values
    ncc_max = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_mean = np.zeros_like(I_filtered, dtype=np.float32)
    ncc_M2 = np.zeros_like(I_filtered, dtype=np.float32)
    n = 0

    # Generate all combinations of angles
    angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]

    # Process combinations in parallel
    results = Parallel(n_jobs=-1)(
        delayed(process_combination1)(
            volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n
        ) for phi, theta, psi in angle_combinations
    )

    # Aggregate results
    for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
        ncc_max = np.maximum(ncc_max, local_ncc_max)
        ncc_mean = local_ncc_mean
        ncc_M2 = local_ncc_M2
        n = local_n

    # Calculate the variance
    ncc_variance = ncc_M2 / (n - 1) if n > 1 else np.zeros_like(I_filtered, dtype=np.float32)

    return ncc_max, ncc_mean, ncc_variance

def process_combination1(volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n):
    """Process a single combination of angles and update relevant statistics."""
    start_time = time.time()
    # Rotate and project
    projection = rotate_and_project_opt(volume, phi, theta, psi)

    # Normalize projection
    projection = projection - np.mean(projection)

    # Band pass filter the projection
    proj_filtered = bandpass_filter(projection, low_sigma=1, high_sigma=5)

    # Normalize the filtered projection
    T_mean = np.mean(proj_filtered)
    T_std = np.std(proj_filtered)
    T_norm = (proj_filtered - T_mean) / T_std

    # Calculate cross-correlation
    #cross_corr = cross_correlate_fourier_opt(I_filtered, T_norm)
    cross_corr = cross_correlate_fourier_gpu(I_filtered, T_norm)
    
    
    # Update max elements
    local_ncc_max = np.maximum(ncc_max, cross_corr)

    # Update mean and variance using Welford's algorithm
    local_n = n + 1
    delta = cross_corr - ncc_mean
    local_ncc_mean = ncc_mean + delta / local_n
    delta2 = cross_corr - local_ncc_mean
    local_ncc_M2 = ncc_M2 + delta * delta2
    end_time = time.time()
    print(f"Cross correlation complete for : {phi, theta, psi} in {end_time-start_time} seconds")
    return local_ncc_max, local_ncc_mean, local_ncc_M2, local_n

# %%
if __name__ == "__main__":
    # Initialize necessary variables here (e.g., volume, phi_angles, theta_angles, psi_angles, etc.)
    # Example:
    # volume = ...
    #volume_file = input("Enter the path to the input MRC volume file: ").strip()
    volume_file = '0_data/7ood.mrc'
    volume, voxel_size = read_mrc_file(volume_file)
    # Get nside from the user
    try:
        nside = int(input("Enter NSIDE parameter (must be a power of 2 integer): "))
        if not hp.isnsideok(nside):
            raise ValueError
    except ValueError:
        print("Error: NSIDE must be a valid power of 2 integer.")
        sys.exit(1)

    print(f"Using NSIDE = {nside} for Healpix sampling.")

    # Get angular spacing from the user
    try:
        angular_spacing = float(input("Enter angular spacing in degrees: "))
        if angular_spacing <= 0:
            raise ValueError
    except ValueError:
        print("Error: Angular spacing must be a positive number.")
        sys.exit(1)
    # phi_angles = ...
    # theta_angles = ...
    # psi_angles = ...
    # Generate phi and theta angles
    phi_angles, theta_angles = generate_all_angles(nside, angular_spacing)
    print(f"Generated {len(phi_angles)} orientations using Healpix.")

    # Generate psi angles
    try:
        psi_step = float(input("Enter psi angular step in degrees: "))
        if psi_step <= 0:
            raise ValueError
    except ValueError:
        print("Error: Psi angular step must be a positive number.")
        sys.exit(1)

    psi_angles = np.arange(0, 360, psi_step)
    print(f"Using {len(psi_angles)} in-plane rotations (psi angles).")

    # Total number of projections
    total_projections = len(phi_angles) * len(psi_angles)
    print(f"Total number of projections to generate: {total_projections}")
    # I_filtered = ...
    with mrcfile.open('0_data/00040_3_0_wctf.mrc', permissive=True) as mrc:
        I = np.squeeze(mrc.data.astype(np.float32))
    # Apply the band-pass filter to the micrograph
    I_filtered = bandpass_filter(I, low_sigma=1, high_sigma=5)
    
    ncc_max, ncc_mean, ncc_variance = parallelize_processing1(
        volume, phi_angles, theta_angles, psi_angles, I_filtered,
    )
# Out:
# Using NSIDE = 1 for Healpix sampling.
# Pixel 1/12: Generated 4 angles
# Pixel 2/12: Generated 6 angles
# Pixel 3/12: Generated 10 angles
# Pixel 4/12: Generated 4 angles
# Pixel 5/12: Generated 4 angles
# Pixel 6/12: Generated 4 angles
# Pixel 7/12: Generated 4 angles
# Pixel 8/12: Generated 4 angles
# Pixel 9/12: Generated 4 angles
# Pixel 10/12: Generated 6 angles
# Pixel 11/12: Generated 10 angles
# Pixel 12/12: Generated 4 angles
# Generated 64 orientations using Healpix.
# Using 6 in-plane rotations (psi angles).
# Total number of projections to generate: 384
# Cross correlation complete for : (1.0471975511965976, 0.0, 60.0) in 58.87573432922363 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 240.0) in 59.235227823257446 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 0.0) in 59.66377115249634 seconds
# Cross correlation complete for : (0.0, 0.0, 300.0) in 60.90847730636597 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 120.0) in 59.596142530441284 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 0.0) in 0.5194926261901855 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 0.0) in 60.89085388183594 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 0.0) in 60.206172466278076 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 0.0) in 59.91883182525635 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 240.0) in 60.59552574157715 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 120.0) in 60.16986680030823 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 180.0) in 61.47395348548889 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 180.0) in 61.35402822494507 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 300.0) in 60.34454679489136 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 60.0) in 0.5720226764678955 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 240.0) in 60.28529214859009 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 300.0) in 60.33306121826172 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 120.0) in 0.443218469619751 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 0.0) in 60.56375241279602 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 0.4218277931213379 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 240.0) in 0.40755558013916016 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 300.0) in 62.33441686630249 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 120.0) in 61.13983941078186 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 61.72653555870056 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 300.0) in 0.45528411865234375 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 240.0) in 61.44239377975464 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 60.0) in 62.782182693481445 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 0.0) in 0.49720263481140137 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 60.0) in 62.215768337249756 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 0.0) in 63.199121952056885 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 60.0) in 61.862311124801636 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 60.0) in 0.48897647857666016 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 300.0) in 62.14269518852234 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 240.0) in 63.48829388618469 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 120.0) in 0.42612171173095703 seconds
# Cross correlation complete for : (0.0, 0.0, 120.0) in 63.80828309059143 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 180.0) in 0.4624500274658203 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 240.0) in 0.518756628036499 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 300.0) in 0.3768622875213623 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 0.0) in 0.4326517581939697 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 60.0) in 0.47122716903686523 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 120.0) in 0.45213747024536133 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 180.0) in 0.37349700927734375 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 240.0) in 0.4005277156829834 seconds
# Cross correlation complete for : (3.141592653589793, 1.0471975511965976, 300.0) in 0.37571120262145996 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 0.0) in 0.38718461990356445 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 60.0) in 0.43383264541625977 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 120.0) in 0.47846150398254395 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 180.0) in 0.43330979347229004 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 240.0) in 0.39324188232421875 seconds
# Cross correlation complete for : (4.1887902047863905, 1.0471975511965976, 300.0) in 0.38387322425842285 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 0.0) in 0.4214301109313965 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 60.0) in 0.3863072395324707 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 120.0) in 0.3816037178039551 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 180.0) in 0.37950682640075684 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 240.0) in 0.3564143180847168 seconds
# Cross correlation complete for : (4.71238898038469, 0.0, 300.0) in 0.38573431968688965 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 0.0) in 0.4176030158996582 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 60.0) in 0.3840169906616211 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 120.0) in 0.454235315322876 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 180.0) in 0.357830286026001 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 240.0) in 0.4625253677368164 seconds
# Cross correlation complete for : (5.759586531581287, 0.0, 300.0) in 0.3505845069885254 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 0.0) in 0.40999341011047363 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 60.0) in 0.3517136573791504 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 120.0) in 0.4679245948791504 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 180.0) in 0.37731122970581055 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 240.0) in 0.3620181083679199 seconds
# Cross correlation complete for : (4.71238898038469, 1.0471975511965976, 300.0) in 0.4157736301422119 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 0.0) in 0.3901529312133789 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 60.0) in 0.4167304039001465 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 120.0) in 0.41739416122436523 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 180.0) in 0.37528395652770996 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 240.0) in 0.41391825675964355 seconds
# Cross correlation complete for : (5.759586531581287, 1.0471975511965976, 300.0) in 0.41100525856018066 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 0.0) in 0.3364872932434082 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 60.0) in 0.3809967041015625 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 120.0) in 0.3695991039276123 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 180.0) in 0.40496134757995605 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 240.0) in 0.4002234935760498 seconds
# Cross correlation complete for : (5.497787143782138, 0.8410686705679303, 300.0) in 0.35858583450317383 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 0.0) in 0.3809630870819092 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 60.0) in 0.35318899154663086 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 120.0) in 0.3528604507446289 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 180.0) in 0.35972070693969727 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 240.0) in 0.408585786819458 seconds
# Cross correlation complete for : (0.0, 0.8410686705679303, 300.0) in 0.3702976703643799 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 0.0) in 0.3506040573120117 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 120.0) in 75.2184054851532 seconds
# Cross correlation complete for : (2.0943951023931953, 1.0471975511965976, 300.0) in 75.39297604560852 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 60.0) in 0.409512996673584 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 120.0) in 0.43022990226745605 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 120.0) in 76.16447472572327 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 180.0) in 0.42381739616394043 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 240.0) in 0.40630388259887695 seconds
# Cross correlation complete for : (5.497787143782138, 1.8882662217645279, 300.0) in 0.33132123947143555 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 0.0) in 0.41519784927368164 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 60.0) in 0.39181995391845703 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 120.0) in 0.43250203132629395 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 180.0) in 0.3795735836029053 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 240.0) in 0.399932861328125 seconds
# Cross correlation complete for : (0.0, 1.8882662217645279, 300.0) in 0.3486173152923584 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 0.0) in 0.3563699722290039 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 60.0) in 0.3977038860321045 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 120.0) in 0.4154195785522461 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 180.0) in 0.35060811042785645 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 240.0) in 0.36444568634033203 seconds
# Cross correlation complete for : (0.7853981633974483, 0.8410686705679303, 300.0) in 0.33599233627319336 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 0.0) in 0.39995336532592773 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 60.0) in 0.34731507301330566 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 120.0) in 0.37479162216186523 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 180.0) in 0.3622722625732422 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 240.0) in 0.3865084648132324 seconds
# Cross correlation complete for : (1.832595714594046, 0.8410686705679303, 300.0) in 0.3473672866821289 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 0.0) in 0.35236406326293945 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 60.0) in 0.3548424243927002 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 120.0) in 0.3457190990447998 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 180.0) in 0.37531495094299316 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 240.0) in 0.34100770950317383 seconds
# Cross correlation complete for : (0.7853981633974483, 1.8882662217645279, 300.0) in 0.39503002166748047 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 0.0) in 0.34281277656555176 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 60.0) in 0.3441648483276367 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 120.0) in 0.3356161117553711 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 180.0) in 0.3971376419067383 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 240.0) in 0.360363245010376 seconds
# Cross correlation complete for : (1.832595714594046, 1.8882662217645279, 300.0) in 0.3534691333770752 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 0.0) in 0.3428030014038086 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 60.0) in 0.38208603858947754 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 120.0) in 0.36072421073913574 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 180.0) in 0.39376211166381836 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 240.0) in 0.3319056034088135 seconds
# Cross correlation complete for : (2.356194490192345, 0.8410686705679303, 300.0) in 0.38297581672668457 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 0.0) in 0.3467698097229004 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 60.0) in 0.3688697814941406 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 120.0) in 0.4185624122619629 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 180.0) in 0.3875749111175537 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 240.0) in 0.33301401138305664 seconds
# Cross correlation complete for : (3.4033920413889422, 0.8410686705679303, 300.0) in 0.3736100196838379 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 0.0) in 0.3608250617980957 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 60.0) in 0.3685576915740967 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 120.0) in 0.34136462211608887 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 180.0) in 0.3769540786743164 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 240.0) in 0.33215832710266113 seconds
# Cross correlation complete for : (2.356194490192345, 1.8882662217645279, 300.0) in 0.3710007667541504 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 0.0) in 0.3521292209625244 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 60.0) in 0.3930225372314453 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 120.0) in 0.4272589683532715 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 180.0) in 0.49253344535827637 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 240.0) in 0.3603854179382324 seconds
# Cross correlation complete for : (3.4033920413889422, 1.8882662217645279, 300.0) in 0.3412961959838867 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 0.0) in 0.4328758716583252 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 60.0) in 0.44600415229797363 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 120.0) in 0.5026295185089111 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 180.0) in 0.5448338985443115 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 240.0) in 0.458620548248291 seconds
# Cross correlation complete for : (3.926990816987241, 0.8410686705679303, 300.0) in 0.47862744331359863 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 0.0) in 0.44707679748535156 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 120.0) in 90.66602659225464 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 60.0) in 0.6139030456542969 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 120.0) in 0.4386720657348633 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 180.0) in 0.4878251552581787 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 240.0) in 0.5534060001373291 seconds
# Cross correlation complete for : (4.974188368183839, 0.8410686705679303, 300.0) in 0.45756006240844727 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 0.0) in 0.4923226833343506 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 60.0) in 0.4455108642578125 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 120.0) in 0.5142624378204346 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 180.0) in 0.49575114250183105 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 240.0) in 0.40682482719421387 seconds
# Cross correlation complete for : (3.926990816987241, 1.8882662217645279, 300.0) in 0.4099845886230469 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 0.0) in 0.5458493232727051 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 60.0) in 0.4110541343688965 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 120.0) in 0.4361763000488281 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 180.0) in 0.4712505340576172 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 240.0) in 0.37891101837158203 seconds
# Cross correlation complete for : (4.974188368183839, 1.8882662217645279, 300.0) in 0.46175241470336914 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 0.0) in 0.5288052558898926 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 60.0) in 0.5550212860107422 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 120.0) in 0.4732844829559326 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 180.0) in 0.5919954776763916 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 240.0) in 0.46603941917419434 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 300.0) in 0.4317915439605713 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 0.0) in 0.4301331043243408 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 60.0) in 0.4643881320953369 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 120.0) in 0.4655721187591553 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 180.0) in 0.4389078617095947 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 240.0) in 0.5446820259094238 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 300.0) in 0.5729386806488037 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 0.0) in 0.5740153789520264 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 60.0) in 0.664332389831543 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 120.0) in 0.5181326866149902 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 180.0) in 0.5760965347290039 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 240.0) in 0.551569938659668 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 300.0) in 0.5230429172515869 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 0.0) in 0.5158872604370117 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 60.0) in 0.5144572257995605 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 120.0) in 0.4734995365142822 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 180.0) in 0.5583541393280029 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 240.0) in 0.4753119945526123 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 300.0) in 0.5604259967803955 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 0.0) in 0.5554986000061035 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 60.0) in 0.4881772994995117 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 120.0) in 0.5251531600952148 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 180.0) in 0.4799845218658447 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 240.0) in 0.5033109188079834 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 300.0) in 0.5492861270904541 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 0.0) in 0.5631637573242188 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 60.0) in 0.6037774085998535 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 120.0) in 0.44452834129333496 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 180.0) in 0.41861796379089355 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 240.0) in 0.4327871799468994 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 300.0) in 0.40799999237060547 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 0.0) in 0.5220646858215332 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 60.0) in 0.4639854431152344 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 120.0) in 0.396852970123291 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 180.0) in 0.488236665725708 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 240.0) in 0.4944732189178467 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 300.0) in 0.41565608978271484 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 0.0) in 0.7648224830627441 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 60.0) in 0.4717874526977539 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 120.0) in 0.5252840518951416 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 180.0) in 0.4143846035003662 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 240.0) in 0.42130160331726074 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 300.0) in 0.5681207180023193 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 0.0) in 0.4468247890472412 seconds
# Cross correlation complete for : (0.0, 0.0, 240.0) in 117.42439866065979 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 60.0) in 0.5674865245819092 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 120.0) in 0.5001688003540039 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 180.0) in 0.5024423599243164 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 240.0) in 0.48328185081481934 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 300.0) in 0.5164892673492432 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 0.0) in 0.5617356300354004 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 60.0) in 0.3785390853881836 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 120.0) in 119.49176931381226 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 120.0) in 0.49013280868530273 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 180.0) in 0.394132137298584 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 240.0) in 0.42856907844543457 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 300.0) in 0.4910714626312256 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 300.0) in 120.62242984771729 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 0.0) in 0.435715913772583 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 60.0) in 0.44364237785339355 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 120.0) in 0.40959787368774414 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 180.0) in 0.5575089454650879 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 240.0) in 0.40399932861328125 seconds
# Cross correlation complete for : (0.0, 1.5707963267948966, 300.0) in 0.504410982131958 seconds
# Cross correlation complete for : (0.0, 0.0, 180.0) in 123.35289669036865 seconds
# Cross correlation complete for : (0.0, 0.0, 0.0) in 122.00632429122925 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 0.0) in 0.465639591217041 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 60.0) in 0.4315531253814697 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 120.0) in 0.4051070213317871 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 180.0) in 122.59715127944946 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 300.0) in 122.80153512954712 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 180.0) in 0.585890531539917 seconds
# Cross correlation complete for : (4.1887902047863905, 0.0, 60.0) in 123.17031669616699 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 240.0) in 0.5347564220428467 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 180.0) in 123.55330204963684 seconds
# Cross correlation complete for : (1.0471975511965976, 1.5707963267948966, 300.0) in 0.525571346282959 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 0.0) in 0.44079017639160156 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 60.0) in 0.44966769218444824 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 120.0) in 0.45488667488098145 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 60.0) in 125.70464563369751 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 180.0) in 0.5838665962219238 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 240.0) in 0.44124388694763184 seconds
# Cross correlation complete for : (2.0943951023931953, 1.5707963267948966, 300.0) in 0.36130738258361816 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 0.0) in 0.4867517948150635 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 60.0) in 0.4362030029296875 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 120.0) in 0.37444448471069336 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 180.0) in 0.4176630973815918 seconds
# Cross correlation complete for : (1.0471975511965976, 1.0471975511965976, 180.0) in 128.41640901565552 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 240.0) in 0.5143158435821533 seconds
# Cross correlation complete for : (3.141592653589793, 1.5707963267948966, 300.0) in 0.5175611972808838 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 0.0) in 0.44483304023742676 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 60.0) in 0.3874385356903076 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 120.0) in 0.37494516372680664 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 180.0) in 0.5350325107574463 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 240.0) in 0.4366753101348877 seconds
# Cross correlation complete for : (4.1887902047863905, 1.5707963267948966, 300.0) in 0.4768080711364746 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 0.0) in 0.5241966247558594 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 60.0) in 0.41884422302246094 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 120.0) in 0.523066520690918 seconds
# Cross correlation complete for : (0.0, 1.0471975511965976, 240.0) in 132.05560898780823 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 180.0) in 0.5853807926177979 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 240.0) in 0.5452885627746582 seconds
# Cross correlation complete for : (0.0, 2.617993877991494, 300.0) in 0.49626708030700684 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 0.0) in 0.44470691680908203 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 60.0) in 0.46443676948547363 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 120.0) in 0.4888923168182373 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 180.0) in 0.3842959403991699 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 240.0) in 0.5308783054351807 seconds
# Cross correlation complete for : (1.0471975511965976, 2.617993877991494, 300.0) in 0.4370760917663574 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 0.0) in 0.3870887756347656 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 60.0) in 0.49369025230407715 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 120.0) in 0.4015216827392578 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 180.0) in 0.4424917697906494 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 240.0) in 0.43052220344543457 seconds
# Cross correlation complete for : (2.0943951023931953, 2.617993877991494, 300.0) in 0.5262231826782227 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 0.0) in 0.4184086322784424 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 60.0) in 0.4862360954284668 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 120.0) in 0.5471868515014648 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 180.0) in 0.5258734226226807 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 240.0) in 0.3892860412597656 seconds
# Cross correlation complete for : (3.141592653589793, 2.617993877991494, 300.0) in 0.5406899452209473 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 0.0) in 0.47742652893066406 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 60.0) in 0.5005409717559814 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 120.0) in 0.5921857357025146 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 180.0) in 0.4359753131866455 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 240.0) in 0.4540591239929199 seconds
# Cross correlation complete for : (0.0, 0.0, 240.0) in 143.12089133262634 seconds
# Cross correlation complete for : (4.1887902047863905, 2.617993877991494, 300.0) in 0.5401372909545898 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 0.0) in 0.5355172157287598 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 60.0) in 0.5831630229949951 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 120.0) in 0.4853241443634033 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 180.0) in 0.5281870365142822 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 240.0) in 0.46285176277160645 seconds
# Cross correlation complete for : (4.71238898038469, 1.5707963267948966, 300.0) in 0.5013649463653564 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 0.0) in 0.6043531894683838 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 60.0) in 145.40402340888977 seconds
# Cross correlation complete for : (1.0471975511965976, 0.0, 120.0) in 146.22595262527466 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 60.0) in 0.45391178131103516 seconds
# Cross correlation complete for : (0.0, 0.0, 120.0) in 146.19321036338806 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 120.0) in 0.5238921642303467 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 180.0) in 0.5080957412719727 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 240.0) in 0.5211391448974609 seconds
# Cross correlation complete for : (5.759586531581287, 1.5707963267948966, 300.0) in 0.5842764377593994 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 0.0) in 0.5119259357452393 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 60.0) in 0.5053155422210693 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 120.0) in 0.5758278369903564 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 180.0) in 0.6226072311401367 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 240.0) in 0.5484914779663086 seconds
# Cross correlation complete for : (4.71238898038469, 2.617993877991494, 300.0) in 0.4873814582824707 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 0.0) in 0.6118619441986084 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 60.0) in 0.8597748279571533 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 120.0) in 0.5716664791107178 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 180.0) in 0.5254569053649902 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 240.0) in 0.5302436351776123 seconds
# Cross correlation complete for : (5.759586531581287, 2.617993877991494, 300.0) in 0.5348513126373291 seconds
# Cross correlation complete for : (3.141592653589793, 0.0, 180.0) in 156.19169569015503 seconds
# Cross correlation complete for : (2.0943951023931953, 0.0, 60.0) in 156.5285849571228 seconds
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/tmp/ipykernel_463168/68292519.py", line 119, in process_combination1
#   File "/tmp/ipykernel_463168/285950068.py", line 6, in cross_correlate_fourier_gpu
#   File "/scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/cupy/_creation/from_data.py", line 88, in asarray
#     return _core.array(a, dtype, False, order, blocking=blocking)
#   File "cupy/_core/core.pyx", line 2408, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2435, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2578, in cupy._core.core._array_default
#   File "cupy/_core/core.pyx", line 137, in cupy._core.core.ndarray.__new__
#   File "cupy/_core/core.pyx", line 225, in cupy._core.core._ndarray_base._init
#   File "cupy/cuda/memory.pyx", line 738, in cupy.cuda.memory.alloc
#   File "cupy/cuda/memory.pyx", line 1424, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1445, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1116, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1137, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc
#   File "cupy/cuda/memory.pyx", line 1382, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
#   File "cupy/cuda/memory.pyx", line 1385, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
# cupy.cuda.memory.OutOfMemoryError: Out of memory allocating 46,190,592 bytes (allocated so far: 0 bytes).
# """
#
# The above exception was the direct cause of the following exception:
#
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 55
#      52 # Apply the band-pass filter to the micrograph
#      53 I_filtered = bandpass_filter(I, low_sigma=1, high_sigma=5)
# ---> 55 ncc_max, ncc_mean, ncc_variance = parallelize_processing1(
#      56     volume, phi_angles, theta_angles, psi_angles, I_filtered,
#      57 )
#
# Cell In[7], line 78, in parallelize_processing1(volume, phi_angles, theta_angles, psi_angles, I_filtered)
#      75 angle_combinations = [(phi, theta, psi) for phi, theta in zip(phi_angles, theta_angles) for psi in psi_angles]
#      77 # Process combinations in parallel
# ---> 78 results = Parallel(n_jobs=-1)(
#      79     delayed(process_combination1)(
#      80         volume, phi, theta, psi, I_filtered, ncc_max, ncc_mean, ncc_M2, n
#      81     ) for phi, theta, psi in angle_combinations
#      82 )
#      84 # Aggregate results
#      85 for local_ncc_max, local_ncc_mean, local_ncc_M2, local_n in results:
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File /scratch/rd_tm/7_Software/miniconda3/envs/py2DTM/lib/python3.10/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# OutOfMemoryError: Out of memory allocating 46,190,592 bytes (allocated so far: 0 bytes).

# %%
# Display the results
plt.figure(figsize=(6, 6))
plt.imshow(ncc_max, cmap='gray')
plt.title('Max Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()

plt.figure(figsize=(6, 6))
plt.imshow(ncc_mean, cmap='gray')
plt.title('Mean Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()

plt.figure(figsize=(6, 6))
plt.imshow(ncc_variance, cmap='gray')
plt.title('Variance Cross-Correlation Map')
plt.colorbar()
plt.axis('off')
plt.show()


# Aggregate the correlation maps by taking the maximum at each pixel
mip = (ncc_max - ncc_mean)/np.sqrt(ncc_variance)

# Display the aggregated cross-correlation map
plt.figure(figsize=(6, 6))
plt.imshow(mip, cmap='gray')
plt.title('Aggregated MIP map')
plt.colorbar()
plt.axis('off')
plt.show()

# %%
# Count the number of elements above 8
num_elements_above_8 = np.sum(mip > 7.43)
print(f"Number of elements in mip_scaled above 8: {num_elements_above_8}")

# %%
# Find the row and column indices of values greater than 7 in the mip array
indices = np.where(mip > 7.43)
rows, cols = indices

# Print the row and column indices in pairs
for row, col in zip(rows, cols):
    print(f"Row: {row}, Col: {col}")

# %%
plt.figure(figsize=(6, 6))
plt.imshow(I_filtered, cmap='gray')

# Add circles for each pair of coordinates
for col, row in zip(cols, rows):
	circle = plt.Circle((col, row), radius=50, color='red', fill=False, linewidth=0.2)
	plt.gca().add_patch(circle)

#plt.scatter(cols, rows, c='red', s=1)
plt.title('Row, Col Indices on Image I')
plt.axis('off')
plt.show()
